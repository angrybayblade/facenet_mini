# %%
import facenet_mini as fm
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow import keras
from sklearn.manifold import TSNE

# %matplotlib inline

# %%
dataset = fm.Dataset("./notebooks/images/train/",n_faces=300)

# %%
dataset.parse()
# Out:
# 100%|██████████| 900/900 [00:01<00:00, 715.59it/s]
# Dataset Parser @ /storage/facenet_mini/notebooks/images/train

# %%
dataset.x.shape
# Out:
# (900, 110, 110, 3)

# %%
model = keras.models.model_from_json(open("./facenet.json","r").read())

# %%
model.load_weights("./facenet")

# %%
emb = model.predict(dataset.x)

# %%
tsne = TSNE(2,)

# %%
enc = tsne.fit_transform(emb)

# %%
plt.figure(figsize=(12,12))
sns.scatterplot(enc[:,0],enc[:,1],hue=dataset.y)
plt.legend("off")
