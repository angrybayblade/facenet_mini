# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

from tqdm.notebook import tqdm

# %matplotlib inline

# %%
pairs = np.load("pairs.npy")

# %%
faces = np.array([
    np.array([cv2.cvtColor(cv2.imread(j),cv2.COLOR_BGR2RGB) for j in i])
    for i in pairs
])

# %%
faces.shape
# Out:
# (22050, 3, 110, 110, 3)

# %%
np.random.shuffle(faces)

# %%
fig,axes = plt.subplots(3,3,figsize=(14,14))

imgs = faces[np.random.randint(0,len(faces),(3,))]

for img,ax in zip(imgs.reshape(-1,110,110,3),axes.reshape(-1)):
    ax.imshow(img)

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras.layers import *

# %%
class Normalize(keras.layers.Layer):
    """
    Normalization Layer For Images
    """
    def __init__(self,):
        super(Normalize,self).__init__()
        
    def __call__(self,x):
        return x/255

# %%
IMG_SIZE=110

# %%
_input = Input(shape=(IMG_SIZE,IMG_SIZE,3))
norm = Normalize()(_input)

conv_0 = Conv2D(32,3,activation="relu",padding="same")(norm)
conv_1 = Conv2D(32,3,activation="relu",padding="same")(concatenate([norm,conv_0]))
conv_2 = Conv2D(32,1,activation="relu",padding="same")(concatenate([norm,conv_0,conv_1]))

norm_1 = BatchNormalization()(concatenate([norm,conv_0,conv_1,conv_2]))
pool_1 = MaxPool2D()(norm_1)

conv_3 = Conv2D(32,3,activation="relu",padding="same")(pool_1)
conv_4 = Conv2D(32,3,activation="relu",padding="same")(concatenate([pool_1,conv_3]))
conv_5 = Conv2D(32,1,activation="relu",padding="same")(concatenate([pool_1,conv_3,conv_4]))

norm_2 = BatchNormalization()(concatenate([pool_1,conv_3,conv_4,conv_5]))
pool_2 = MaxPool2D()(norm_2)

conv_6 = Conv2D(64,3,activation="relu",padding="same")(pool_2)
conv_7 = Conv2D(64,3,activation="relu",padding="same")(concatenate([pool_2,conv_6]))
conv_8 = Conv2D(64,1,activation="relu",padding="same")(concatenate([pool_2,conv_6,conv_7]))

norm_3 = BatchNormalization()(concatenate([pool_2,conv_6,conv_7,conv_8]))
pool_3 = MaxPool2D()(norm_3)

conv_9 = Conv2D(64,3,activation="relu",padding="same")(pool_3)
conv_10 = Conv2D(64,3,activation="relu",padding="same")(concatenate([pool_3,conv_9]))
conv_11 = Conv2D(64,1,activation="relu",padding="same")(concatenate([pool_3,conv_9,conv_10]))

norm_4 = BatchNormalization()(concatenate([pool_3,conv_9,conv_10,conv_11]))
pool_4 = MaxPool2D()(norm_4)

flat = Flatten()(pool_4)
dense_1 = Dense(2048)(flat)
dense_1 = LeakyReLU()(dense_1)
dense_2 = Dense(1024)(dense_1)
dense_2 = LeakyReLU()(dense_2)
out = Dense(128,activation="sigmoid")(dense_2)

net = keras.Model(_input,out)

# %%
net.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 110, 110, 3) 0
# __________________________________________________________________________________________________
# tf_op_layer_truediv (TensorFlow [(None, 110, 110, 3) 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 110, 110, 32) 896         tf_op_layer_truediv[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 110, 110, 35) 0           tf_op_layer_truediv[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 110, 110, 32) 10112       concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 110, 110, 67) 0           tf_op_layer_truediv[0][0]
#                                                                  conv2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 110, 110, 32) 2176        concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 110, 110, 99) 0           tf_op_layer_truediv[0][0]
#                                                                  conv2d[0][0]
#                                                                  conv2d_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 110, 110, 99) 396         concatenate_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 55, 55, 99)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 55, 55, 32)   28544       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 55, 55, 131)  0           max_pooling2d[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 55, 55, 32)   37760       concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 55, 55, 163)  0           max_pooling2d[0][0]
#                                                                  conv2d_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 55, 55, 32)   5248        concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 55, 55, 195)  0           max_pooling2d[0][0]
#                                                                  conv2d_3[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 55, 55, 195)  780         concatenate_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 27, 27, 195)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 27, 27, 64)   112384      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 27, 27, 259)  0           max_pooling2d_1[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 27, 27, 64)   149248      concatenate_6[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 27, 27, 323)  0           max_pooling2d_1[0][0]
#                                                                  conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 27, 27, 64)   20736       concatenate_7[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 27, 27, 387)  0           max_pooling2d_1[0][0]
#                                                                  conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 27, 27, 387)  1548        concatenate_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 13, 13, 387)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 13, 13, 64)   222976      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 13, 13, 451)  0           max_pooling2d_2[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 13, 13, 64)   259840      concatenate_9[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 13, 13, 515)  0           max_pooling2d_2[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 13, 13, 64)   33024       concatenate_10[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 13, 13, 579)  0           max_pooling2d_2[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 13, 13, 579)  2316        concatenate_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 579)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 20844)        0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2048)         42690560    flatten[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 2048)         0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         2098176     leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          131200      leaky_re_lu_1[0][0]
# ==================================================================================================
# Total params: 45,807,920
# Trainable params: 45,805,400
# Non-trainable params: 2,520
# __________________________________________________________________________________________________

# %%
a_inp = Input(shape=(IMG_SIZE,IMG_SIZE,3),name="anc")
p_inp = Input(shape=(IMG_SIZE,IMG_SIZE,3),name="pos")
n_inp = Input(shape=(IMG_SIZE,IMG_SIZE,3),name="neg")

a_net = net(a_inp)
p_net = net(p_inp)
n_net = net(n_inp)

train = keras.Model([a_inp,p_inp,n_inp],concatenate([a_net,p_net,n_net]))

# %%
train.output_shape
# Out:
# (None, 384)

# %% [markdown]
# ### Triplet

# %% [markdown]
# ![](triplet.png)

# %%
class Triplet(object):
    """
    Triplet Loss
    """
    def __init__(self,margin=0.5,dist="mse"):
        self.margin = margin
        self.dist = self.__getattribute__(dist)
    
    def mse(self,x,y):
        return tf.reduce_sum(tf.square(tf.subtract(x,y)))
    
    def __call__(self,y_true,y_pred,*args,**kwargs):
        a_pred,p_pred,n_pred = tf.unstack(tf.reshape(y_pred,(3,-1,128)))
        Dp = self.dist(a_pred,p_pred)
        Dn = self.dist(a_pred,n_pred)
        return tf.nn.relu(Dp - Dn + self.margin)

# %%
triplet = Triplet(margin=1)

# %%
train.compile(optimizer="adam",loss=triplet)

# %%
train.fit(
    (faces[:,0,:,:,:],faces[:,1,:,:,:],faces[:,2,:,:,:]),
    tf.zeros((len(faces),128*3)),
    batch_size=4,
    epochs = 30
)
# Out:
# Train on 22050 samples
# Epoch 1/30
# 22050/22050 [==============================] - 594s 27ms/sample - loss: 1.0016
# Epoch 2/30
# 10440/22050 [=============>................] - ETA: 6:16 - loss: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-7201b56f5ff9> in <module>
#       3     tf.zeros((len(faces),128*3)),
#       4     batch_size=4,
# ----> 5     epochs = 30
#       6 )
#
# c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# c:\python36\lib\site-packages\tensorflow_core\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     566
#     567   return pack_sequence_as(
# --> 568       structure[0], [func(*x) for x in entries],
#     569       expand_composites=expand_composites)
#     570
#
# c:\python36\lib\site-packages\tensorflow_core\python\util\nest.py in <listcomp>(.0)
#     566
#     567   return pack_sequence_as(
# --> 568       structure[0], [func(*x) for x in entries],
#     569       expand_composites=expand_composites)
#     570
#
# c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in _non_none_constant_value(v)
#     128
#     129 def _non_none_constant_value(v):
# --> 130   constant_value = tensor_util.constant_value(v)
#     131   return constant_value if constant_value is not None else v
#     132
#
# c:\python36\lib\site-packages\tensorflow_core\python\framework\tensor_util.py in constant_value(tensor, partial)
#     820   """
#     821   if isinstance(tensor, ops.EagerTensor):
# --> 822     return tensor.numpy()
#     823   if not is_tensor(tensor):
#     824     return tensor
#
# c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py in numpy(self)
#     940     """
#     941     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 942     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     943     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     944
#
# c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py in _numpy(self)
#     906     # pylint: disable=protected-access
#     907     try:
# --> 908       return self._numpy_internal()
#     909     except core._NotOkStatusException as e:
#     910       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:
